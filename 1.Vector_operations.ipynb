# %% [markdown]
# # Part-1 in this repo we will wok with the below you can check on
# # 1.Addition and subtracttion of a vector,
#
# # 2.multiplication a vector by scalar ,
#
# # 3.and how the negative values reduces the vectors 📊📊📊

# %%
import numpy as np
# import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# # here quiver simply represents an arrow

# %%
plt.quiver(0,0,4,5,color ='y')
plt.show()

# %%
plt.quiver(0,0,4,5,scale_units ='xy',angles ='xy',scale=1,color='r')
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %%
plt.quiver(0,0,4,5,scale_units ='xy',angles ='xy',scale=2,color='r')
plt.xlim(-10,10)
plt.ylim(-10,10)
plt.show()

# %% [markdown]
# # addition of two vectors

# %%
vector_1 = np.array([0,0,2,3])

vector_2 = np.array([0,0,3,-2])

sum = vector_1 +vector_2

# %%
sum
# Out:
# array([0, 0, 5, 1])

# %% [markdown]
# # Now representing them graphically

# %%
plt.quiver(0,0,2,3,scale_units= 'xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,3,-2,scale_units= 'xy',angles='xy',scale=1,color='r')

plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
plt.quiver(0,0,2,3,scale_units= 'xy',angles='xy',scale=1,color='b')
plt.quiver(0,0,3,-2,scale_units= 'xy',angles='xy',scale=1,color='r')
plt.quiver(0,0,5,1,scale_units= 'xy',angles='xy',scale=1,color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# # Subtracting the vectors

# %%
vector_1 = np.array([0,0,2,3])
vector_2= np.array([0,0,2,-3])

vector_subtraction = vector_1 - vector_2

print(vector_subtraction)
# Out:
# [0 0 0 6]

# %% [markdown]
# # its time to rpresent them graphically

# %%
plt.quiver(0,0,2,3,scale_units = 'xy',scale =1,angles='xy',color = 'b')
plt.quiver(0,0,2,-3,scale_units = 'xy',scale =1,angles='xy',color = 'g')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %%
plt.quiver(0,0,2,3,scale_units = 'xy',scale =1,angles='xy',color = 'b')
plt.quiver(0,0,2,-3,scale_units = 'xy',scale =1,angles='xy',color = 'g')
plt.quiver(0,0,0,6,scale_units = 'xy',scale =1,angles='xy')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# # Multiplying a vector  by a scaler

# %%
vector_1 = np.asarray([0,0,4,5])

scalar =3

multiplying = vector_1*scalar
print(multiplying)
# Out:
# [ 0  0 12 15]

# %%
plt.quiver(0,0,4,5,scale=1,scale_units = 'xy',angles = 'xy',color = 'b')
plt.xlim(-9,9)
plt.ylim(-9,9)
plt.show()

# %%
plt.quiver(0,0,4,5,scale=1,scale_units = 'xy',angles = 'xy',color = 'b')
plt.quiver(0,0,12,15,scale = 1,scale_units = 'xy',angles = 'xy',color='y')
plt.xlim(-9,9)
plt.ylim(-9,9)
plt.show()

# %% [markdown]
# # If there   is a vector with negative values then

# %%
vector_1 = np.asarray([0,0,2,3])

vector_2 = -0.5*vector_1

print(vector_2)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0,2,3, scale_units='xy', angles='xy', scale=1, color='b')
plt.quiver(0,0,-1,-1.5, scale_units='xy', angles='xy', scale=1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
